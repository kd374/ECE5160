# %%
# %load_ext autoreload
# %autoreload 2

from ble import get_ble_controller
from base_ble import LOG
from cmd_types import CMD
import time
import numpy as np

LOG.propagate = False
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Get ArtemisBLEController object
ble = get_ble_controller()

# Connect to the Artemis Device
ble.connect()
# Out:
# 2025-03-04 22:15:45,013 | INFO     |: Looking for Artemis Nano Peripheral Device: c0:83:24:6c:39:3c
# 2025-03-04 22:15:49,357 | INFO     |: Connected to c0:83:24:6c:39:3c

# %%
ble.send_command(CMD.CALIBRATION, "0|0|0|34") # pins "[PIN0, PIN1], [PIN2, PIN3]"
# Out:
# 2025-03-04 22:39:53,577 | INFO     |: Disconnected from C0:83:24:6C:39:3C
