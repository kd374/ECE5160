# %%
# %load_ext autoreload
# %autoreload 2

from ble import get_ble_controller
from base_ble import LOG
from cmd_types import CMD
import time
import numpy as np

LOG.propagate = False

# %%
# Get ArtemisBLEController object
ble = get_ble_controller()

# Connect to the Artemis Device
ble.connect()
# Out:
# 2025-03-10 22:20:27,218 | INFO     |: Looking for Artemis Nano Peripheral Device: c0:83:24:6c:39:3c
# 2025-03-10 22:20:31,810 | INFO     |: Connected to c0:83:24:6c:39:3c
# C:\Users\Katyas Laptop\Documents\ECE5160\ble_robot_1.2_last_week\ble_robot_1.2\ble_python\base_ble.py:104: FutureWarning: This method will be removed future version, pass the callback to the BleakClient constructor instead.
#   self.client.set_disconnected_callback(self.disconnect_handler)

# %%
ble.send_command(CMD.CALIBRATION, "80|80|80|80") # pins "[PIN0, PIN1], [PIN2, PIN3]"

# %%
ble.disconnect()
# Out:
# 2025-03-10 22:21:53,144 | INFO     |: Disconnected from C0:83:24:6C:39:3C
